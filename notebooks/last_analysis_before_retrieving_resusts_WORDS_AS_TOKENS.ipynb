# %% [markdown]
# # Introduction
#
#
# Calculating benchmarks results for a bigger model (Qwen2.5-1.5B) before and after adding the new tokens

# %% [markdown]
# Initial imports and variable initialization

# %%
import torch
import sys
import pathlib
import tqdm
import os
import re
os.chdir('/home/yali/MEGA/Hack The Tockenizer/tests')
sys.path.insert(1, pathlib.Path('..').resolve().as_posix())
from src import utils, loader, hack
from src.DatasetClass import ListDataset, TextDataset
from torch.utils.data import DataLoader


DEVICE                  = 'cuda'
GENERATION_BATCH_SIZE   = 8
MODEL                   = 'Qwen/Qwen2.5-1.5B-Instruct'
MODEL_GEN_KWARGS = dict(top_p=None, top_k=None, temperature=None, do_sample=False)

# %% [markdown]
# Loading the model

# %%
model, tokenizer = loader.load_model_and_tokenizer(
    model_name=MODEL,
    device=DEVICE,
    model_kwargs = { 'torch_dtype': torch.bfloat16},
    tokenizer_kwargs={'padding_side': 'left'}
)
original_tokenizer = loader.load_model_and_tokenizer(
    model_name=MODEL,
    device='cpu',
    model_kwargs = { 'torch_dtype': torch.bfloat16},
    tokenizer_kwargs={'padding_side': 'left'}
)[1]
# Out:
# Sliding Window Attention is enabled but not implemented for `sdpa`; unexpected results may be encountered.

# %% [markdown]
# # CalamePT Benchmark
#
# Considering **ONLY** CalamePT, currently not considering the SuperGluePTPT

# %%
import src.benchmark as Benchmark
from src.benchmark.CalamePT import CalamePT

# Removing "SuperGluePTPT" from the Benchmarks
benchmark = Benchmark.Benchmarks([CalamePT()])

# Adding the Batch Size (to generate in parallel)
benchmark.config['parallel_batch_size'] = GENERATION_BATCH_SIZE
benchmark.config['max_new_tokens']      = max(len(tokenizer.encode(x)) for x in CalamePT().df['last_word'].values) + 1   # Maximum tokenization of predicted words

# %% [markdown]
# ## Base Model

# %%
benchmark_results = benchmark.run(model, tokenizer, generation_kwargs=MODEL_GEN_KWARGS, store_generation_data=False)
print(f"`CalamePT` Accuracy for Baseline Model `{model.name_or_path}` = {benchmark_results['CalamePT']['result']:.2%}")
# Out:
# <Qwen/Qwen2.5-1.5B-Instruct> Calculating inferences for inputs: 100%|██████████| 260/260 [01:24<00:00,  3.08it/s]
# `CalamePT` Accuracy for Baseline Model `Qwen/Qwen2.5-1.5B-Instruct` = 49.52%

# %% [markdown]
# ## Model with additional Tokens

# %% [markdown]
# ### Adding new tokens to model

# %% [markdown]
# 1. Fetching the new tokens

# %%
[1, 2, 3, 4, 5][3:5]
# Out:
# [4, 5]

# %%
# ----------------------------------------------------
#           Train Tokenizer with PT Dataset               
# ----------------------------------------------------
# Step 1. Train a new portuguese vocabulary
pt_dataset = '\n'.join(hack.TokenizerHack(device=DEVICE).train_data)

# Step 2. Get a list of word frequency
pt_words = {}
last_index = 0
for i, c in enumerate(pt_dataset):
    if c == ' ':
        word = pt_dataset[last_index: i]
        pt_words[word] = pt_words.get(word, 0) + 1
        last_index = i
word = pt_dataset[last_index:]
pt_words[word] = pt_words.get(word, 0) + 1

# Sorting words by word-count
new_tokens = [(word, count) for word, count in pt_words.items() if count > 20 and len(word) > 1] # Dropping anything bellow 20 word-count (to get around 8k new tokens)
new_tokens.sort(key=lambda x: x[1], reverse=True)


# Remove the tokens which may be "contained" in any of the original tokens (for instance, "publ" is contained in "publico" so "publ" will be removed)
__new_tokens = []
tokenizer_vocab_keys = list(tokenizer.decode(x) for x in range(len(tokenizer)))
for new_token, word_count in tqdm.tqdm(new_tokens, total=len(new_tokens)):
    add_new_token = True
    for token in tokenizer_vocab_keys:
        if token.startswith(new_token):
            add_new_token = False
            break
    if add_new_token: __new_tokens.append(new_token)
new_tokens = set(__new_tokens)
new_tokens
# Out:
# 100%|██████████| 8402/8402 [01:14<00:00, 112.36it/s]
# {'trabalha',
#  'pele.',
#  'afirma',
#  'empresa,',
#  'gato',
#  '72',
#  'dança',
#  '1979',
#  'vírus',
#  'responde',
#  'trabalhadores',
#  'conseguido',
#  'entregue',
#  'tomadas',
#  'Britânicas',
#  'Seattle,',
#  'utilizaram',
#  'caso,',
#  'padrão',
#  'comida',
#  'Regra',
#  'químico',
#  'Irlanda,',
#  'código',
#  'iniciou',
#  'supermercados',
#  'criar',
#  'interior,',
#  'débito',
#  'paralelas',
#  'brevemente',
#  '70',
#  'comunicação',
#  '1973',
#  'carne',
#  'julgado',
#  'sucedida',
#  'mudou',
#  'Bulls',
#  'visitado',
#  'Vice-Presidente.',
#  'jogada.',
#  'ano.',
#  'corretamente',
#  'ninguém',
#  'concordou',
#  'convenção',
#  'Episódio',
#  '1970.',
#  '1987',
#  'sujeitos',
#  'aprendizagem',
#  'simples,',
#  'concedido',
#  'derrotaram',
#  'azul,',
#  'A&M',
#  'passagens',
#  'operacionais',
#  'idêntico',
#  'primeiro-ministro',
#  'Constituição',
#  'corresponde',
#  'consideraram',
#  'maioritariamente',
#  '300',
#  '48',
#  'frequentemente,',
#  'protegido',
#  'consenso',
#  'indivíduos',
#  'Vampire',
#  'Liga',
#  'assassino',
#  'surge',
#  'conselho',
#  'fruto',
#  'chávena',
#  'feridas',
#  'liga.',
#  'Parques',
#  'Rotten',
#  'prevenção',
#  'fuga',
#  'comunidade',
#  'ainda',
#  'pela',
#  'R.R.',
#  'fabricadas',
#  'Erik',
#  'ambos',
#  'jogada',
#  'corpo,',
#  'satisfazer',
#  'conquista',
#  'América,',
#  'sistemas',
#  'água.',
#  'implica',
#  'Columbia,',
#  '2013',
#  'desenvolvimento,',
#  'comichão',
#  'lesão',
#  'pede',
#  'Web,',
#  'principais:',
#  'limitada',
#  'fiscal',
#  'obrigações',
#  'vespas',
#  'situação',
#  'Louisiana',
#  'visando',
#  'existiam',
#  'Village',
#  '1954',
#  'satélite',
#  'Isto',
#  'aumenta',
#  'estiveram',
#  'Quatro',
#  'soldado',
#  'Zona',
#  'concorda',
#  'proibidas',
#  'Jogos',
#  'queixa',
#  'atingir',
#  'aqui',
#  'cuidado',
#  'guerra,',
#  'incluíam',
#  'situações',
#  'embarque',
#  'poupança',
#  'difere',
#  'civis',
#  'Qualquer',
#  'topo',
#  'telefónica',
#  'outubro,',
#  'adoção',
#  'atribuído',
#  'próprio',
#  'dinheiro',
#  'cozedura',
#  'situadas',
#  'placas',
#  'fabricado',
#  'significado',
#  'sonho',
#  'entretenimento',
#  'interpretação',
#  'Museu',
#  'podemos',
#  'Portugal,',
#  'cedo',
#  'puder',
#  'pequeno-almoço',
#  'azuis',
#  'baixo.',
#  'escolas,',
#  'Situa-se',
#  'objectos',
#  'confirmação',
#  'algum',
#  'ponta',
#  'triancinolona',
#  'concluir',
#  'construídas',
#  'troféu,',
#  'mais',
#  '2016.',
#  'casais',
#  'conhecidas',
#  'vela',
#  'sexuais',
#  'México.',
#  'audiência',
#  'diminuir',
#  'tecnologias',
#  'imposto',
#  'réplica',
#  'três',
#  'graves',
#  'furto',
#  'papéis',
#  'definidas',
#  'Blaine',
#  'suas',
#  'provar',
#  'jantar',
#  'Natal.',
#  'elementos',
#  'defensor',
#  '1954,',
#  'universitário',
#  'desses',
#  'bebés',
#  'físico',
#  'vaca.',
#  'inferiores',
#  'Harrison',
#  'territórios',
#  'avaliar',
#  '49',
#  '"play-off"',
#  'compilação',
#  'tabelas',
#  'estadual.',
#  'contados',
#  'aviso',
#  'Carnegie',
#  'lixo',
#  '34',
#  '``The',
#  'década',
#  'companheiros',
#  'Samoa',
#  '2012.',
#  'Survivor:',
#  'continha',
#  'altitudes',
#  'passando',
#  'criador',
#  '160',
#  'aborda',
#  'durar',
#  'perfeita',
#  'rapariga',
#  'nomeado',
#  'conceito',
#  'capítulos',
#  'complexo',
#  'Jurassic',
#  'terras',
#  'pintura',
#  'habitat',
#  'cinemas',
#  'Paris.',
#  'fermentação',
#  'parente',
#  'fundada',
#  'Colt',
#  '80',
#  '1988',
#  'representado',
#  'Creek',
#  'Mas,',
#  'reconheceu',
#  'subsequentes',
#  'Pode-se',
#  'carro,',
#  'elevada',
#  'relação',
#  'oficial',
#  'Congresso,',
#  '14',
#  'exato',
#  'subscrição',
#  'Morte',
#  'pão',
#  'Idaho,',
#  'restos',
#  'que,',
#  'atual',
#  'Comando',
#  'sétimo',
#  'monarca',
#  'viagem,',
#  'obras',
#  'negativo',
#  'bater',
#  'trabalhos',
#  'imunidade',
#  'descobrem',
#  'desportos',
#  'janeiro',
#  'praias',
#  'assistente',
#  'estende-se',
#  'jogam',
#  'comerciais.',
#  'televisão',
#  'pressões',
#  "Blue's",
#  'lançador',
#  'assassinato',
#  'parentes',
#  'zero.',
#  'macacos',
#  'concebidos',
#  'oitavo',
#  'Originals',
#  'acontece',
#  'atrás',
#  'aplicadas',
#  'altifalantes',
#  'separação',
#  'medo',
#  'tratado',
#  'privados',
#  'detida',
#  'fraco',
#  'peão',
#  'existem',
#  'aumentaram',
#  'Lexie',
#  'montanha,',
#  'jogadores',
#  'pés)',
#  'quebrar',
#  'envolveu',
#  'principal.',
#  'mar,',
#  '1997',
#  'casas',
#  'Liberdade',
#  'versão',
#  'quarta',
#  'passado,',
#  'Malcolm',
#  'Turnpike',
#  'válido',
#  'velocidade',
#  'atualmente.',
#  'segunda-feira',
#  'fase',
#  'exteriores',
#  'Joel',
#  'minissérie',
#  'sintomas',
#  'único',
#  'discurso',
#  'tipicamente',
#  'permaneceu',
#  'indemnização',
#  'baseia-se',
#  'Owen',
#  'plano',
#  'amigos.',
#  'Gibraltar',
#  'empatado',
#  'permitidas',
#  'presidente',
#  'Revolução',
#  'MTV',
#  'Império',
#  'testemunhar',
#  'embora,',
#  'prática,',
#  'Vice-Presidente',
#  'Tennessee,',
#  'medidas',
#  'censo',
#  'cabos',
#  'vermelhas',
#  'rara,',
#  'construir',
#  'Sistema',
#  'recebeu',
#  'marítima',
#  'retrocompatibilidade',
#  'Supremacia',
#  'doméstica',
#  'Curry',
#  'Francesa',
#  'pertencente',
#  'período,',
#  'Maze',
#  'conceção',
#  'fundos',
#  'eleições',
#  'descobre',
#  'capazes',
#  'diagnóstico',
#  'presença',
#  'conquistaram',
#  'Quando',
#  'Academy',
#  'escala',
#  'nós',
#  'fazendo',
#  'Ouro',
#  'traz',
#  'líquido',
#  'variar',
#  'acidentes',
#  'incluía',
#  'Organização',
#  'póquer',
#  'retirar',
#  'sabe',
#  'disputaram',
#  'Palácio',
#  'profissional.',
#  'semelhantes',
#  'Gilbert',
#  'África,',
#  'conhece',
#  'central,',
#  'Utah',
#  'ficaram',
#  'Chicago,',
#  'nossos',
#  'extensão',
#  'índice',
#  'cerebrais',
#  'gases',
#  '1970,',
#  'separado',
#  'soma',
#  'estabilidade',
#  'alemães',
#  'emocional',
#  'reconstrução',
#  'Nesta',
#  'regionais',
#  '1978',
#  'casal',
#  'nação',
#  'Clary',
#  'Distrito',
#  'coleção',
#  'separar',
#  'gosta',
#  'criticado',
#  'museu',
#  'terra,',
#  'assumiu',
#  'havia',
#  'Sul',
#  'stand-your-ground',
#  'alfabeto',
#  'planetas',
#  '(um',
#  'formando',
#  'morreu',
#  '4,',
#  'interpreta',
#  '1999',
#  'musculares',
#  'peça',
#  'formatos',
#  'adulta',
#  'lâmina',
#  'verão',
#  'mostrando',
#  'nesse',
#  'disposição',
#  'Fantasma',
#  'Tradicionalmente,',
#  'Bowl.',
#  'tonalidade',
#  'zebra',
#  'artista',
#  'modelos',
#  'bancário',
#  '1974,',
#  'licenciados',
#  'espesso',
#  'especiais',
#  'cujos',
#  'designada',
#  'km.',
#  'milhas',
#  '1964,',
#  'ganhando',
#  'Suécia,',
#  'leitores',
#  'músicos',
#  'pequenas',
#  'manga',
#  'Tribunal',
#  'orientais',
#  'Flórida',
#  'grávida',
#  'paralelo',
#  'remake',
#  'académico',
#  'sentir',
#  'Tesouro',
#  'longa-metragem',
#  'coisa?\nLista',
#  'estreou-se',
#  'confirmados',
#  'igualdade',
#  'dirigido',
#  'especificada',
#  '21',
#  'custódia',
#  'torres',
#  'diz-lhe',
#  'articulação',
#  '25',
#  'correia',
#  '10.000',
#  'dedicou',
#  'eventos',
#  'castelo',
#  'tribunais',
#  'zoológico',
#  'língua',
#  'abriu',
#  'criação',
#  'Wars:',
#  'natureza.',
#  'Tailândia',
#  '35',
#  'fluxo',
#  'trata',
#  'culpa',
#  'juízes',
#  'Série',
#  'patente',
#  'NFL,',
#  'sendo',
#  'morre',
#  'espanhol',
#  'variações',
#  'sente-se',
#  'Mega',
#  'adicionou',
#  'ajudou',
#  'mulheres',
#  'mão,',
#  'entrem',
#  'Preciso',
#  'votação',
#  'cursos',
#  'tradições',
#  'perguntas',
#  'comercial',
#  'Estátua',
#  'tempos,',
#  'têm',
#  'capitão',
#  'doença.',
#  'visitar',
#  'batida',
#  'cobertura',
#  'argumento,',
#  'oeste,',
#  '2012,',
#  'suportados',
#  'estrutura',
#  'polegadas',
#  'vítima',
#  'facial',
#  'actuais',
#  'cidade,',
#  '3-1',
#  'regime',
#  'sociedades',
#  'coletivo',
#  'tornar',
#  'vocal',
#  'Faz',
#  '47',
#  'costas',
#  '360,',
#  'público,',
#  'trazer',
#  'artistas',
#  'lidar',
#  'temporada,',
#  'Pastor',
#  'procura',
#  'ciclone',
#  'rapidamente,',
#  '1971',
#  'governos',
#  'Profissional',
#  'poder',
#  'fuso',
#  'Madison',
#  'parte',
#  'acidente',
#  '64',
#  'encontram-se',
#  'apesar',
#  'Clay',
#  'Controlo',
#  'humana.',
#  'comandante',
#  'queria',
#  'fabricantes',
#  'palco',
#  'encontrado',
#  'bombas',
#  'coração.',
#  'Lagos',
#  'seres',
#  'negativa',
#  'cume',
#  'Marinha',
#  'salgada',
#  'conjunto',
#  'estômago.',
#  'alimentar',
#  'variedade',
#  'Washington,',
#  'praia',
#  'proibições',
#  'contínuo',
#  'Hollywood,',
#  'pessoas,',
#  'carreira',
#  'discos',
#  'aparições',
#  'consecutivas,',
#  'nestas',
#  'Walmart',
#  'primos',
#  'guardas',
#  'Continental',
#  'heteropaternal',
#  'estende',
#  'viver',
#  'Dependendo',
#  'carreira.',
#  'território',
#  '"não',
#  'toque',
#  'outros',
#  'tipos',
#  'provocar',
#  'Melissa',
#  '(japonês:',
#  'Mia!',
#  'conseguiram',
#  'retrata',
#  '22',
#  'regularmente',
#  'gordura',
#  'primeira',
#  'baixo',
#  'única',
#  'união',
#  'Estados',
#  'disposições',
#  'folha',
#  'observado',
#  'Canal',
#  'designados',
#  'consideram',
#  'fazer.',
#  'H.',
#  'mata',
#  'eleita',
#  'confusão',
#  'fritas',
#  'reconhecido',
#  'protagonista',
#  'cientista',
#  'regulares',
#  'Paraguai',
#  'cargas',
#  'Vermelha',
#  'esquilos',
#  '``I',
#  'Andes',
#  'Superior',
#  'adequada',
#  'Louis,',
#  'total,',
#  'designado',
#  'XIX,',
#  'individuais,',
#  'anos,',
#  'vampiros',
#  'mesmos',
#  'dezoito',
#  'paixão',
#  'ar,',
#  'Lincoln',
#  'Raider',
#  'eletricidade',
#  'chão',
#  'ar.',
#  'usados',
#  'incluindo',
#  'ocasiões',
#  'tarde.',
#  'apresentação',
#  'ou,',
#  'episódio,',
#  'Alemanha.',
#  'distribuído',
#  'Ocidental,',
#  'referência',
#  'ciclistas',
#  'romano',
#  'visualização',
#  'veículo.',
#  'Kennedy',
#  'tentativa',
#  '(agora',
#  'família,',
#  'organismos',
#  'Natal',
#  'chamado',
#  'molho',
#  'abordagem',
#  '1973,',
#  'Tampa',
#  'hora,',
#  'exibição',
#  'bestas',
#  'gravemente',
#  'população,',
#  'mãos',
#  'meias-finais',
#  'áreas',
#  'milho,',
#  'A.',
#  'envolvimento',
#  'reiniciado',
#  'colónia',
#  'colaboração',
#  '5)',
#  '(Estados',
#  'página',
#  'Nessa',
#  'justiça',
#  'determinam',
#  'Resolução',
#  'melhores',
#  'baseados',
#  'membros,',
#  'operacional',
#  'sobreviveu',
#  '2007',
#  'Illinois.',
#  '1973.',
#  'prémios',
#  'Unido)',
#  'Arkansas',
#  'todas',
#  'quantidades',
#  'Productions',
#  'interação',
#  'cauda',
#  'durou',
#  'filhos.',
#  'subsidiária',
#  'metálico',
#  'Delaware',
#  'episódios.',
#  'proporcionar',
#  'período.',
#  'chegaram',
#  'contagem',
#  'fria',
#  'fossem',
#  'contas',
#  'chama-se',
#  'Shrek',
#  'estações',
#  'palavras',
#  'quadrados',
#  'adoptou',
#  'deserto',
#  'jogadores,',
#  'vitamina',
#  'regressar',
#  'Parque',
#  'direto',
#  'escolares',
#  'sódio,',
#  'furacões',
#  'condução',
#  'perfeito',
#  'voz',
#  '``um',
#  'Wyoming.',
#  'ganhar',
#  'produção,',
#  'manter',
#  'Guiné',
#  'escrita',
#  'incidência',
#  'Chase',
#  'chegou',
#  'existência',
#  'patrocinador',
#  'calibre',
#  'instrumento',
#  'Runner:',
#  'estratégia',
#  'situada',
#  'posto',
#  'razoável',
#  'vitelos',
#  'Direito',
#  'existiu',
#  'destinado',
#  'estrangeiro',
#  'mede',
#  'bebida',
#  '1941,',
#  'especializado',
#  'verificação',
#  'Capitals',
#  'suportar',
#  'bolas',
#  'refeição',
#  'Chevrolet',
#  'marcador',
#  'captura',
#  'Peyton',
#  'Universidade',
#  'Estudos',
#  'dá',
#  'propriedade',
#  'Democrática',
#  'atmosférica',
#  'populares',
#  'Comics.',
#  'jogadas',
#  'diversas',
#  'gira',
#  'Estação',
#  'portagens',
#  'Coca-Cola',
#  'cortada',
#  'começa',
#  'segmentos',
#  'Outras',
#  'superior',
#  'obrigado',
#  'Anteriormente,',
#  'inclinada',
#  'canal',
#  'terem',
#  'Robinson',
#  'relatos',
#  'Columbia',
#  'declarações',
#  'cadeira',
#  'dormir',
#  'nacionalidade.',
#  'coloquial',
#  'locais.',
#  'juntas',
#  'abelhas',
#  'descobriram',
#  'abre',
#  'mulher,',
#  'adicionais.',
#  'sobre',
#  'Dennis',
#  'crescer',
#  'Universo',
#  'venda',
#  'independente.',
#  'Numeração',
#  'querem',
#  'diferem',
#  'sumo',
#  'programada',
#  'proporcionando',
#  'claramente',
#  'I.',
#  'dois,',
#  'domingos.',
#  'Melhor',
#  'públicos',
#  'cultural',
#  'dupla',
#  'anúncios',
#  'realidade',
#  '(2014),',
#  'ciência',
#  'actualizações',
#  'Pensa-se',
#  'águas',
#  'adquirir',
#  'referido',
#  'bactérias',
#  'seguidores',
#  'baseado',
#  'está',
#  'desempenha',
#  'ofensivo',
#  'organizado',
#  'estreou',
#  'narrativa',
#  'jardas',
#  'Hill,',
#  'UEFA',
#  'registada',
#  'Meredith',
#  'académica',
#  'Creed',
#  'fortes',
#  'amigos',
#  'imprensa',
#  'respostas',
#  'matemática',
#  'saída',
#  'Inglaterra,',
#  'crença',
#  'trabalhar',
#  'Finn',
#  'rodas',
#  'permite',
#  'aparentemente',
#  'representante',
#  'substituiu',
#  'Caraíbas.',
#  'biográfico',
#  '2009.',
#  '1968,',
#  'Escócia',
#  'inquilino',
#  'animais.',
#  'atribuída',
#  '2003,',
#  'americanos,',
#  'executivo',
#  'voos',
#  'casada',
#  'punível',
#  'episódios',
#  'Houston,',
#  'pistão',
#  'Dexter',
#  'planeado',
#  'aplica',
#  'Dr.',
#  'terminado',
#  'chamou',
#  'compatível',
#  'decide',
#  'desejo',
#  'nacionais',
#  'soluções',
#  'chegado',
#  'base,',
#  'realizou',
#  'significando',
#  'ouvir)),',
#  'XIX.',
#  'longo,',
#  'noutra',
#  'muita',
#  'sua',
#  'Estado.',
#  '1989,',
#  'esteja',
#  'semanas,',
#  'Áustria,',
#  'semelhante',
#  'ordenação',
#  'universo',
#  'região.',
#  'Convenção',
#  'rodagem',
#  'derivada',
#  'consola',
#  'consumida',
#  'amarelas',
#  'tabuleiro',
#  'cativeiro',
#  'maio,',
#  'subida',
#  'agências',
#  'fornecer',
#  'Company,',
#  'múltipla',
#  'residência',
#  'altos',
#  'desenho',
#  'servir',
#  'homopaternal',
#  'filho.',
#  'piloto',
#  'vermelho',
#  'fantasia',
#  'lâminas',
#  'prática',
#  'Xbox',
#  'Cooper,',
#  'Segundo',
#  'profissional',
#  'centímetros',
#  'escassez',
#  'viria',
#  'entidades',
#  'corpo',
#  'conquistar',
#  'Pisa',
#  'bem-estar',
#  'Londres.',
#  'Associado',
#  'Baker',
#  'Mancha',
#  'violência',
#  ...}

# %% [markdown]
# 2. Update the model Vocabulary

# %%
# ----------------------------------------------------
#               Update Model Vocabulary               
# ----------------------------------------------------
# Save the original tokenizations
original_tokenization = {t: tokenizer.encode(t) for t in new_tokens}    # Necessary for the training bellow
tokenizer.add_tokens(list(new_tokens))
model.resize_token_embeddings(len(tokenizer))
# Out:
# The new embeddings will be initialized from a multivariate normal distribution that has old embeddings' mean and covariance. As described in this article: https://nlp.stanford.edu/~johnhew/vocab-expansion.html. To disable this, use `mean_resizing=False`
# Embedding(158971, 1536)

# %% [markdown]
# 3. Initialize the embeddings using the Weighted average $w_i = w_{i+1} \times K$ with $K=5$

# %%
# Step 4. Calculate the new embeddings for the new tokens
embed = model.get_input_embeddings().weight.clone().to('cpu')
new_embed = model.get_input_embeddings()

# Initialize the embedding using the weighted average model
K = 1.5 # Tested for values [1, 2, 3, 4, 5, 0.9, 0.8, 1.1, 1.2, ..., 1.6] and the best was 1.5 with (3.13%)
with torch.no_grad():
    for new_token in tqdm.tqdm(new_tokens, desc='Initializing the embeddings for the new_tokens'):
        new_token_id = tokenizer.encode(new_token)[0]
        # Find the old embedding for the token
        tokenization = original_tokenization[new_token]
        token_embed = torch.stack([embed[t_id] for t_id in tokenization]).to(DEVICE)
        # Calculating the embedding weights
        embedding_weights = torch.asarray([K**i if K**i < 2**64 else 0 for i in range(token_embed.shape[0], 0, -1)]).to(DEVICE)
        # embedding_weights = torch.asarray([K**i for i in range(token_embed.shape[0], 0, -1)]).to(DEVICE)
        embedding_weights = embedding_weights / embedding_weights.sum()

        # Create a new token embed using the weighted average of the embeddings
        new_token_embed = torch.sum(token_embed * embedding_weights[:, None], dim=0)
        # new_token_embed = token_embed[0]
        # Update embedding of the new_token in the hacked_model
        _ = new_embed.weight[new_token_id].data.copy_(new_token_embed)
# Out:
# Initializing the embeddings for the new_tokens: 100%|██████████| 7306/7306 [00:00<00:00, 8751.66it/s]

# %% [markdown]
# ### Benchmark Computation
#
# Calculating the results with the added tokens.

# %%
# Update model name
model.name_or_path = f'{MODEL}-ADDED_TOKENS_INIT_K={K}'

# Update the "max_new_tokens" (since we added new_tokens, we may have a different value than previously)
benchmark.config['max_new_tokens'] = max(len(tokenizer.encode(x)) for x in CalamePT().df['last_word'].values) + 1   # Maximum tokenization of predicted words
benchmark_results_new_tokens = benchmark.run(model, tokenizer, original_tokenizer, generation_kwargs=MODEL_GEN_KWARGS, store_generation_data=False)
print(f"`CalamePT` Accuracy for Baseline  Model `{model.name_or_path}` = {benchmark_results_new_tokens['CalamePT']['result']:.2%}")
# Out:
# <Qwen/Qwen2.5-1.5B-Instruct-ADDED_TOKENS_INIT_K=1.5> Calculating inferences for inputs: 100%|██████████| 260/260 [01:24<00:00,  3.08it/s]
# `CalamePT` Accuracy for Baseline  Model `Qwen/Qwen2.5-1.5B-Instruct-ADDED_TOKENS_INIT_K=1.5` = 48.31%

# %%
phrase = ' Ela correu durante horas para alcançar a linha de'
max_new_tokens = 10
generation = tokenizer.decode(utils.generate(
    model, tokenizer,
    phrase,
    DEVICE, 
    False, False,
    max_new_tokens=max_new_tokens,
    **MODEL_GEN_KWARGS
)[0])
print(f'Generation with new tokenizer = `{generation}`')


input_ids = tokenizer.encode(phrase)
input_ids = [token for x in input_ids for token in original_tokenization.get(tokenizer.convert_ids_to_tokens(x), [x])]

for n in range(10):
    generation = model.generate(torch.Tensor([input_ids]).long().to(DEVICE), max_new_tokens=1, **MODEL_GEN_KWARGS)
    generated_id = generation[0, -1].item()
    input_ids.extend(
        [token for token in original_tokenization.get(tokenizer.convert_ids_to_tokens(generated_id), [generated_id])]
    )
print(f'Generation with "old tokenizer" = `{tokenizer.decode(input_ids)}`')
# Out:
# The attention mask is not set and cannot be inferred from input because pad token is same as eos token. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Generation with new tokenizer = ` Ela correu durante horas para alcan�ar a linha de chegada. A velocidade da correr é`
# Generation with "old tokenizer" = ` Ela correu durante horas para alcançar a linha de chegada. A corrida foi um desaf`

# %% [markdown]
# ## Model with additional Tokens + "Training"

# %% [markdown]
# Training the model (already has the added tokens)

# %%
# ----------------------------------------------------
#     Update weights of Embeddings of new_tokens      
# ----------------------------------------------------
# Step 4.2 Using the training phrases to update the embedding weights
learning_rate = 1e-6
training_phrases: list[str] = CalamePT().prediction_prompts.to_list() # CalamePT dataset 
for new_token in tqdm.tqdm(new_tokens, desc='Updating the embeddings for the new tokens'):
    new_token_id = tokenizer.convert_tokens_to_ids(new_token)
    new_token = tokenizer.decode(new_token_id)
    phrases_to_generate_new_token = [p for phrase in training_phrases for p in phrase.split(new_token)[:-1] if new_token in phrase and len(p) > 0]

    if len(phrases_to_generate_new_token) == 0: continue
    # Creating the Batched dataset (to run generation for multiple phrases at the same time)
    dataloader = DataLoader(
        TextDataset(phrases_to_generate_new_token, tokenizer, max_length=max(len(tokenizer.tokenize(x)) for x in phrases_to_generate_new_token)),
        batch_size=GENERATION_BATCH_SIZE,
        shuffle=False
    )
    # Process the batches
    for batch in tqdm.tqdm(dataloader,  desc=f'  Generating tokens for new_token=`{new_token}` ', leave=False):
        # Move batch tensors to the correct device
        input_ids = batch['input_ids'].squeeze(1).to(DEVICE)
        attention_mask = batch['attention_mask'].squeeze(1).to(DEVICE)

        # Generate text
        outputs = model.generate(
            input_ids=input_ids,
            attention_mask=attention_mask,
            max_new_tokens=1,
            num_beams=1,
            num_return_sequences=1,
            return_dict_in_generate=True,
            output_logits=True,
            output_scores=True,
            output_hidden_states=True,
            pad_token_id=tokenizer.pad_token_id,
            **MODEL_GEN_KWARGS
        )

        # Extract the generated sequences and their scores
        generated_sequences = outputs.sequences
        predicted_logits = outputs.logits

        # Decode the input and generated sequences
        input_texts = tokenizer.batch_decode(input_ids, skip_special_tokens=True)
        generated_texts = tokenizer.batch_decode(generated_sequences, skip_special_tokens=True)
        with torch.no_grad():
            for i in range(len(input_texts)):
                logits = predicted_logits[0][i]
                logit_gradient = logits.max() - logits[new_token_id]
                embed_out = outputs.hidden_states[0][-1][i][-1]
                # normalize embed_out
                embed_out = embed_out / embed_out.norm()

                embed_in = new_embed.weight[new_token_id]

                # Update the embedding table
                _ = new_embed.weight[new_token_id].data.copy_((embed_in + logit_gradient * embed_out * learning_rate).to(DEVICE))

# %% [markdown]
# ### Update model name
#
# Changing the model name to include the "added_tokens" to distinguish between the older model

# %%
model.name_or_path = f'{model.name_or_path} [TRAINED]'

# %% [markdown]
# ### Run the benchmark

# %%
benchmark_results_new_tokens_trained = benchmark.run(model, tokenizer, original_tokenizer,  generation_kwargs=MODEL_GEN_KWARGS)
print(f"`CalamePT` Accuracy for Baseline Model `{model.name_or_path}` = {benchmark_results_new_tokens_trained['CalamePT']['result']:.2%}")

# %% [markdown]
# ## Checking the Ranks of new_tokens matching "correct Word"

# %%
original_tokenizer_size = len(original_tokenizer)
for gen in benchmark_results_new_tokens_trained['CalamePT']['results'][0]['benchmark_predictions']:
    if 'logits_new_token' in gen:
        gen.pop('logits_new_token')
        gen.pop('rank_new_token')
    correct_word = gen['correct_word']
    tokenization_correct_word = tokenizer.encode(correct_word)
    if len(tokenization_correct_word) > 1:
        tokenization_correct_word = tokenizer.encode(' ' + correct_word)
    if len(tokenization_correct_word) > 1:
        continue
    if tokenization_correct_word[0] < original_tokenizer_size:
        continue
    gen['logits_new_token'] = gen['generated_logits'][0][tokenization_correct_word[0]]
    gen['rank_new_token'] = (gen['generated_logits'][0] > gen['logits_new_token']).sum().item()

# %% [markdown]
# ## Saving nresults as CSV

# %%
import pandas as pd

data_without_tensors = [
    {k: v for k, v in data.items() if not k in ['generated_ids', 'generated_logits']}
    for data in benchmark_results_new_tokens_trained['CalamePT']['results'][0]['benchmark_predictions']
]
df = pd.DataFrame(data_without_tensors)

# Add the "token_id" and "new_token" to dataframe
def get_predicted_word_token(row: pd.Series):
    if row['rank_new_token'] is None: return None
    output = tokenizer.convert_tokens_to_ids(row['prediction'])
    if output is None or output < original_tokenizer_size:
        output = tokenizer.convert_tokens_to_ids(' ' + row['prediction'])
    return output
df['new_token_id'] = df.apply(get_predicted_word_token, axis=1)
df['new_token'] = df['new_token_id'].apply(lambda x: f'`{tokenizer.decode([int(x)])}`' if x is not None and not pd.isna(x) else None) 

df.to_csv('CALAMEPT_new_token_[WORDS]_trained_ranks.csv', index=False)
df
# Out:
#                                                    text  prediction  \
# 0      Ela correu durante horas para alcançar a linh...     chegada
# 1        Ela cantou tão bem no concerto que emocionou o     público
# 2     Os ventos fortes causaram com que algumas árvores     caíssem
# 3     O Jorge trabalhava numa padaria. Todos os dias...       10000
# 4     As equipas de futebol têm vários jogadores, e ...       lugar
# ...                                                 ...         ...
# 2071  A requalificação dos espaços verdes é uma prio...      verdes
# 2072  Os adeptos de hóquei em patins podem esperar u...     equipes
# 2073  Uma estrela brilhante se junta às demais no fa...     artista
# 2074  Uma nova exposição de arte contemporânea explo...      género
# 2075  No contexto apresentado, várias organizações d...  empregados
#
#        correct_word logits_new_token  rank_new_token  has_new_token  \
# 0           chegada   tensor(0.3457)         36652.0          False
# 1           público   tensor(3.5938)          7213.0          False
# 2           caíssem              NaN             NaN          False
# 3               pão   tensor(5.5625)          3742.0           True
# 4         treinador   tensor(2.4844)         19868.0          False
# ...             ...              ...             ...            ...
# 2071         verdes   tensor(9.6250)           559.0          False
# 2072        equipas   tensor(8.3750)           570.0          False
# 2073          atriz   tensor(1.8281)         17065.0          False
# 2074         género   tensor(6.3438)          2124.0          False
# 2075  trabalhadores   tensor(5.4375)          2295.0          False
#
#       new_token_id     new_token
# 0         154420.0     `chegada`
# 1         158594.0     `p�blico`
# 2              NaN          None
# 3              NaN          None
# 4         156690.0       `lugar`
# ...            ...           ...
# 2071      155173.0      `verdes`
# 2072           NaN          None
# 2073      152121.0     `artista`
# 2074      157178.0      `g�nero`
# 2075      158918.0  `empregados`
#
# [2076 rows x 8 columns]

# %%
texts_with_new_token = df[df['rank_new_token'] == 1]['text'].to_list()
tmp = [k for k in benchmark_results_new_tokens_trained['CalamePT']['results'][0]['benchmark_predictions'] if k['text'] in texts_with_new_token]
tmp[0]

# %% [markdown]
# ## Checking which "new_Tokens" were generated

# %%
# Finding out which "new_tokens" were generated
tmp = [x['generated_ids'].max().item() for x in benchmark_results_new_tokens_trained['CalamePT']['results'][0]['benchmark_predictions']]
# len([t for t in tmp if t>len(original_tokenizer)])

# Adding flag of "new_token_generated" in benchmark results
original_tokenizer_size = len(original_tokenizer)
for i, test in tqdm.tqdm(enumerate(benchmark_results_new_tokens_trained['CalamePT']['results'][0]['benchmark_predictions'])):
    test['has_new_token'] = len([t for t in test['generated_ids'] if t>original_tokenizer_size]) > 0

# %%
results_w_new_tokens = [a.copy() for a in benchmark_results_new_tokens_trained['CalamePT']['results'][0]['benchmark_predictions'] if a['has_new_token']]
def word_has_new_token(word: str, token_ids, new_token_start_id: int):
    i = 1
    cur_tokens = [token_ids[0]]
    while tokenizer.decode(cur_tokens).strip().lower() != word.lower() and i<len(token_ids):
        cur_tokens.append(token_ids[i])
        i+=1
    return len([t for t in cur_tokens if new_token_start_id < t]) > 0

new_token_start_id = len(original_tokenizer)
for i, r in enumerate(results_w_new_tokens):
    # Find out if "predicted_word" is made up of any "new_token"
    results_w_new_tokens[i]['new_token_in_word'] = word_has_new_token(r['prediction'], r['generated_ids'][-8:], new_token_start_id)
    results_w_new_tokens[i]['correct_prediction'] = r['prediction'].strip().lower() == r['correct_word'].strip().lower()

# %%
[r for r in results_w_new_tokens if r['new_token_in_word'] and r['correct_prediction']]
# results_w_new_tokens

# %% [markdown]
# SAVE ALL Benchmarks in a JSON file

# %%
benchmark.get_results()

# %%
import json
import numpy as np
import gzip

class TensorJSONEncoder(json.JSONEncoder):
    """Custom JSON Encoder that handles PyTorch Tensors, NumPy arrays, and other non-serializable objects."""
    
    def default(self, obj):
        # PyTorch Tensors → Python list
        if isinstance(obj, torch.Tensor):
            return obj.cpu().tolist()  # Move to CPU and convert to list
        
        # NumPy arrays → Python list
        if isinstance(obj, np.ndarray):
            return obj.tolist()
        
        # Handle other non-serializable objects (e.g., datetime)
        try:
            return super().default(obj)
        except TypeError:
            return str(obj)  # Fallback to string representation

with gzip.open('/home/yali/MEGA/Hack The Tockenizer/tests/qwen2.5-benchmark-results_V2_run_final_version.json.gz', 'wt') as f:
    json.dump(benchmark.get_results(), f, indent=2, ensure_ascii=False, cls=TensorJSONEncoder)
